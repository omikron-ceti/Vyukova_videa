# %% [markdown]
# # For cykly
# ------------

# %% [markdown]
# **Jaké hodnoty vypíše následující program?** (Formátování na jeden řádek zanedbejte)
# **A)**
# **B)**
# **C)**
# **D)**
# **E)**
# **F)**
# **G)**
