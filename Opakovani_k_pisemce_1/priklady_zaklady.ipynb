# %% [markdown]
# # Základy
# (příklady ze starých testů)

# %% [markdown]
# **Co vypíše následující program?**
# **A)** Hello, Bob
# **B)** Hello Bob
# **C)** "Hello, Alice"
# **D)** "Hello", Bob
# **E)** Hello, Alice
# **F)** Hello Alice

# %%
Bob = "Alice"
print("Hello", Bob)

# %% [markdown]
# **Vyberte všechny možnosti, kde proměnná `a` obsahuje komplexní číslo s reálnou částí rovnou 1 a imaginární částí rovnou 2:**
# **A)**
# ```python
# a = 1 + 2i
# ```
# **B)**
# ```python
# a = 1 + 2j
# ```
# **C)**
# ```python
# a = complex(1, 2)
# ```
# **D)**
# ```python
# a = complex(2, 1)
# ```
# **E)**
# ```python
# a = complex(-2, 1).conjugate()
# ```
# **F)**
# ```python
# a = complex(1, -2).conjugate()
# ```

# %%
# Zkuste si: Odkomentujte si postupně jednotlivé možnosti. Bacha, něco vám bude házet chyby.

#a = (1 + 2i)
#a = (1 + 2j)
#a = complex(1, 2)
#a = complex(2, 1)
#a = complex(-2, 1).conjugate()
#a = complex(2, -1).conjugate()

#print(a, type(a))

# %% [markdown]
# **Co vypíše následující program?**
# **A)** 1_2_0_1
# **B)** 1201.
# **C)** 1201.0
# **D)** 0.1201
# **E)** 1201
# **F)** něco jiného (napište co)
# **G)** v programu je syntaktická chyba

# %%
print(1_2_0_1.)
