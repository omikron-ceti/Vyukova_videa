# %% [markdown]
# # Základy
# ------------------------------------------

# %% [markdown]
# **Co vypíše následující program?**
# **A)** Hello, Bob
# **B)** Hello Bob
# **C)** "Hello, Alice"
# **D)** "Hello", Bob
# **E)** Hello, Alice
# **F)** Hello Alice

# %%
Bob = "Alice"
print("Hello", Bob)
# Out:
# Hello Alice

# %% [markdown]
# **Co vypíše následující program?**
# **A)** Hello, Alice
# **B)** Hello Alice
# **C)** "Hello, Bob"
# **D)** "Hello", Alice
# **E)** Hello, Bob
# **F)** Hello Bob

# %%
Alice = "Bob"
print("Hello", Alice)
# Out:
# Hello Bob

# %% [markdown]
# ---
# **Co vypíše následující program?**
#
# **A)** x + x + 1
# **B)** 'x + ', 9
# **C)** x + 9
# **D)** x + 17
# **E)** '19'
# **F)** 33
# **G)** 'x + ' 4 ** 2 + 1

# %%
x = 4 ** 2
print("x + ", x + 1)
# Out:
# x +  17

# %% [markdown]
# <details>
#   <summary>Poznámka</summary>
#
# Technicky vzato ani jedna odpověď není dobře, protože mezi + a 17 jsou dvě mezery.
#
# </details>
