# %% [markdown]
# # Základy
# ------------------------------------------

# %% [markdown]
# **Co vypíše následující program?**
# **A)** Hello, Bob
# **B)** Hello Bob
# **C)** "Hello, Alice"
# **D)** "Hello", Bob
# **E)** Hello, Alice
# **F)** Hello Alice

# %%
Bob = "Alice"
print("Hello", Bob)
# Out:
# Hello Alice
