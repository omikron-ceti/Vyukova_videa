# %% [markdown]
# # Základy
# ------------------------------------------

# %% [markdown]
# **Co vypíše následující program?**
# **A)** Hello, Bob
# **B)** Hello Bob
# **C)** "Hello, Alice"
# **D)** "Hello", Bob
# **E)** Hello, Alice
# **F)** Hello Alice

# %%
Bob = "Alice"
print("Hello", Bob)
# Out:
# Hello Alice

# %% [markdown]
# **Co vypíše následující program?**
# **A)** Hello, Alice
# **B)** Hello Alice
# **C)** "Hello, Bob"
# **D)** "Hello", Alice
# **E)** Hello, Bob
# **F)** Hello Bob

# %%
Alice = "Bob"
print("Hello", Alice)
# Out:
# Hello Bob
