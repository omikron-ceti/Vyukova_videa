# %% [markdown]
# # Knihovny
# ---

# %% [markdown]
# **Vyberte, které z následujících možností obsahují platný kód v jazyce Python, který načte z modulu `math` konstantu `pi` a funkci `cos`:**
#
# **A)** `import pi, cos from math`
# **B)** `import math from cos, pi`
# **C)** `from pi import math, cos`
# **D)** `from math import pi, cos`
# **E)** `import pi, cos`
#
# Zkuste si:

# %%
#A)
import pi, cos from math
# Out:
#   Cell In[1], line 2
#     import pi, cos from math
#                    ^
# SyntaxError: invalid syntax

# %%
#B)
import math from cos, pi
# Out:
#   Cell In[2], line 2
#     import math from cos, pi
#                 ^
# SyntaxError: invalid syntax

# %%
#C)
from pi import math, cos
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #C)
# ----> 2 from pi import math, cos
#
# ModuleNotFoundError: No module named 'pi'

# %%
#D)
from math import pi, cos

# %%
#E)
import pi, cos
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 #E)
# ----> 2 import pi, cos
#
# ModuleNotFoundError: No module named 'pi'
