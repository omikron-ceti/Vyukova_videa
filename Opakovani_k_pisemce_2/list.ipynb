# %% [markdown]
# # `list`
# ---
#
# **Co vypíše následující program?**
# **A)** `[1, 2, 1]`
# **B)** `[1, 2, 2]`
# **C)** 1
# **D)** 2
# **E)** 3

# %%
a = [1, 2][1] + 1

print(a)
# Out:
# 3

# %% [markdown]
# ---
#
# **Co vypíše následující program?**
#
# **A)** 0
# **B)** 1
# **C)** 2
# **D)** nastane chyba `IndexError`

# %%
s = [1, 2]
print(s[len(s)])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 s = [1, 2]
# ----> 2 print(s[len(s)])
#
# IndexError: list index out of range

# %% [markdown]
# `len(s)` je rovna 2, ale samotné `s` má jen prvky na pozici 0 a 1. Na pozici 2 nic není.

# %% [markdown]
# ---
#
# **Vyberte všechny příkazy, které jsou syntakticky správně a definují proměnnou typu `list` (seznam):**
#
# ```python
# a = ()                  e = [1,2,3]
# b = []                  f = [1;2;3]
# c = list("ababa")       g = [1 2 3]
# d = [{}]                h = [1.2,3.4]
#
# ```

# %%
# a
vyraz = "()" 
try: vysledek = eval(vyraz)
except: print(f"A) {vyraz}:  Blbina")
else: print(f"A) {vyraz}: {type(vysledek)}")

# b
vyraz = '[]' 
try: vysledek = eval(vyraz)
except: print(f"B) {vyraz}:  Blbina")
else: print(f"B) {vyraz}: {type(vysledek)}")

# c
vyraz = 'list("ababa")' 
try: vysledek = eval(vyraz)
except: print(f"C) {vyraz}:  Blbina")
else: print(f"C) {vyraz}: {type(vysledek)}")

# d
vyraz = '[{}]' 
try: vysledek = eval(vyraz)
except: print(f"D) {vyraz}:  Blbina")
else: print(f"D) {vyraz}: {type(vysledek)}")

# e
vyraz = '[1,2,3]'
try: vysledek = eval(vyraz)
except: print(f"E) {vyraz}:  Blbina")
else: print(f"E) {vyraz}: {type(vysledek)}")

# f
vyraz = '[1;2;3]'
try: vysledek = eval(vyraz)
except: print(f"F) {vyraz}:  Blbina")
else: print(f"F) {vyraz}: {type(vysledek)}")

# g
vyraz = '[1 2 3]' 
try: vysledek = eval(vyraz)
except: print(f"G) {vyraz}:  Blbina")
else: print(f"G) {vyraz}: {type(vysledek)}")

# h
vyraz = '[1.2,3.4]' 
try: vysledek = eval(vyraz)
except: print(f"H) {vyraz}:  Blbina")
else: print(f"H) {vyraz}: {type(vysledek)}")
# Out:
# A) (): <class 'tuple'>
# B) []: <class 'list'>
# C) list("ababa"): <class 'list'>
# D) [{}]: <class 'list'>
# E) [1,2,3]: <class 'list'>
# F) [1;2;3]:  Blbina
# G) [1 2 3]:  Blbina
# H) [1.2,3.4]: <class 'list'>

# %% [markdown]
# ---
#
# **Jak dopadne spuštění následujícího programu**
#
# **A)** nastane chyba `IndexError`
# **B)** `x` má hodnotu "a"
# **C)** `x` má hodnotu "b"
# **D)** `x` má hodnotu "c"

# %%
my_list = ["a", "b", "c"]
x = my_list[1]

print(x, type(x))
# Out:
# b <class 'str'>
