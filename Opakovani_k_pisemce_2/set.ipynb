# %% [markdown]
# # `set`
# ---
#
# **Jaká bude hodnota proměnné `c` po spuštění následujícího kódu?**
#
# **A)** 2
# **B)** 3
# **C)** {2, 2}
# **D)** jiná (uveďte jaká)
# **E)** program skončí kvůli chybě

# %%
a = {1, 2, 3, 4, 2}
c = a[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 a = {1, 2, 3, 4, 2}
# ----> 2 c = a[2]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Set nemá jasně definované pořadí prvků a proto k nim **nelze přistupovat pomocí indexu**

# %% [markdown]
# ---
#
# **Vyberte všechny příkazy, které jsou syntakticky správně a definují proměnnou typu `set` (množina):**
# ```python
# a = {1:2}                   e = {}
# b = {1,2:3,4}               f = {0}
# c = {1.2, 3.4}              g = {1:2, 3:4}
# d = {1, 2, 3, 4}            h = {1, 1, 1, 1}
# ```

# %%
# a
vyraz = "{1:2}" 
try: vysledek = eval(vyraz)
except: print(f"A) {vyraz}:  Blbina")
else: print(f"A) {vyraz}: {type(vysledek)}")

# b
vyraz = '{1,2:3,4}' 
try: vysledek = eval(vyraz)
except: print(f"B) {vyraz}:  Blbina")
else: print(f"B) {vyraz}: {type(vysledek)}")

# c
vyraz = '{1.2, 3.4}' 
try: vysledek = eval(vyraz)
except: print(f"C) {vyraz}:  Blbina")
else: print(f"C) {vyraz}: {type(vysledek)}")

# d
vyraz = '{1, 2, 3, 4}' 
try: vysledek = eval(vyraz)
except: print(f"D) {vyraz}:  Blbina")
else: print(f"D) {vyraz}: {type(vysledek)}")

# e
vyraz = '{}'
try: vysledek = eval(vyraz)
except: print(f"E) {vyraz}:  Blbina")
else: print(f"E) {vyraz}: {type(vysledek)}")

# f
vyraz = '{0}'
try: vysledek = eval(vyraz)
except: print(f"F) {vyraz}:  Blbina")
else: print(f"F) {vyraz}: {type(vysledek)}")

# g
vyraz = '{1:2, 3:4}' 
try: vysledek = eval(vyraz)
except: print(f"G) {vyraz}:  Blbina")
else: print(f"G) {vyraz}: {type(vysledek)}")

# h
vyraz = '{1, 1, 1, 1}' 
try: vysledek = eval(vyraz)
except: print(f"H) {vyraz}:  Blbina")
else: print(f"H) {vyraz}: {type(vysledek)}")
# Out:
# A) {1:2}: <class 'dict'>
# B) {1,2:3,4}:  Blbina
# C) {1.2, 3.4}: <class 'set'>
# D) {1, 2, 3, 4}: <class 'set'>
# E) {}: <class 'dict'>
# F) {0}: <class 'set'>
# G) {1:2, 3:4}: <class 'dict'>
# H) {1, 1, 1, 1}: <class 'set'>
