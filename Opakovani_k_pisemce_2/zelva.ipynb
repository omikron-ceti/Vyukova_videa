# %%
import turtle

def ukonceni(): # pomocná funkce aby mi necrashoval kernel při opakovaném spuštění
    turtle.done()

    try:
        turtle.bye()
    except:
        print("bye")

# %% [markdown]
# # Turtle
# ---
# **Nakreslete trajektorii zanechanou na papíře želvou po spuštění následujícího programu. Předpokládejte, že na začátku míří želva nahoru.**

# %%
turtle.setheading(90) # přidáno aby želva mířila nahoru

a = 360
b = a / 3
for i in range(3):
    turtle.forward(a)
    turtle.right(b)

ukonceni() # tohle je tady navíc, protože mi crashoval kernel po každém spuštění želvy xDDD
# Out:
# bye

# %% [markdown]
# <img src="img/zelva1.jpg" width="450px"/>

# %% [markdown]
# ---
# **Nakreslete trajektorii zanechanou na papíře želvou po spuštění následujícího programu. Předpokládejte, že na začátku míří želva nahoru.**

# %%
turtle.setheading(90) # přidáno aby želva mířila nahoru


a = 360 / 4
for i in range(2):
    turtle.forward(a)
    turtle.right(a)
    turtle.backward(a)
    turtle.left(-a)

ukonceni()
# Out:
# bye

# %% [markdown]
# <img src="img/zelva2.jpg" width="450px"/>
